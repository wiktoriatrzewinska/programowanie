# %%
import pandas as pd

import numpy as np

import matplotlib as plt

# %%
df_tytanic = pd.read_csv("/content/drive/MyDrive/train.csv")

df_tytanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_tytanic["Sex"]
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
df_titanic['Sex2'] = df_titanic['Sex'].map({'female': 1, 'male': 0})

# %%
df_titanic[['Sex', 'Sex2']].head()
# Out:
#       Sex  Sex2
# 0    male     0
# 1  female     1
# 2  female     1
# 3  female     1
# 4    male     0

# %%
df_titanic[['Sex', 'Sex2']].head(20)
# Out:
#        Sex  Sex2
# 0     male     0
# 1   female     1
# 2   female     1
# 3   female     1
# 4     male     0
# 5     male     0
# 6     male     0
# 7     male     0
# 8   female     1
# 9   female     1
# 10  female     1
# 11  female     1
# 12    male     0
# 13    male     0
# 14  female     1
# 15  female     1
# 16    male     0
# 17    male     0
# 18  female     1
# 19  female     1
